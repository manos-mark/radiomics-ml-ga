# %%
#https://github.com/PacktPublishing/Hands-On-Genetic-Algorithms-with-Python/blob/master/Chapter07/zoo.py

import random
import os

import pandas as pd
from pandas import read_csv

from sklearn import model_selection
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier
import radiomics

# %%
# testing the class:
def main():
    # create a problem instance:
    rad = radiomics.Radiomics(randomSeed=42)

    allOnes = [1] * len(rad)
    print("-- All features selected: ", allOnes, ", accuracy = ", rad.getMeanAccuracy(allOnes))


if __name__ == "__main__":
    main()
# Out:
# /home/manos/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# ...
